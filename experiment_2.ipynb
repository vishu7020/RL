# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishu6744/RL/blob/main/experiment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#np.random.seed(1)
x=np.random.randint(0,50,1000)
y=x+ np.random.randint(0,10,1000)
print(y)
# Out:
# [12 19 17 15 18 50 28 35 43 41 12 48  8 53 27 34 17 10 26 22  9 30 12 36
#  20 34 18  5 38 45 27 22 42 10 47 33 41 34 17 41 49 19 26 12  3 13 48 51
#  19  8 24 45 28 51 26 41 17 55 36 20 14 38 29 30 42 32 25 27 58 16 22 20
#  44  8 17 21 24 15  2  7  7 42 41 22 45 21 29 51 55 52 14 42 21 51 30 20
#  33 49 47  6  9 18 47  5 37 14 36 29 41 10 24 23 50 38 36 23 38 35 39 17
#  16 53 44 36 17 26 15 18 45  3 49 21 30 58 48 20 48 22 33 34 20 24 26 45
#  31 16 38 49 51 35 43 45 40 26  6 25 26 40 37 47 50 47 12 19 58 31 41 47
#  16  2 27 37 35 18 12  5 16 20 42 42 23 36 29 46 43 17 20 14 32 40 51 55
#  44 45  0 30 25 23 11 55 36 50 14  4 30 21 30 54 10 25 20 54 18 16 18 15
#  24 25 21 23 54 32 50 46 29 35 18 21 35 21 15 25 40 49 16 47 30 49  8 40
#  38 47 35 11 17 29 27 46 10 21 38 34 34 27 34 45  4 29 39  8 10 19 46 40
#  27 48 55  7 18 37 31 23  4 30 42 34 12 45 31 52 32 19 24 47 18 43 43 53
#  21 38 49 21 39 43 18  6 28 35 40 46 49 16 28 12 28  2 37 17 49 43 39 41
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use("ggplot")
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.random.randint(0,50,1000)
z=100-x
print(z)
# Out:
# [ 78  79  52  67  70  69  96  62  93  63  95  62  88  64  68  54  60  83
#   71  86  65  65  69  70  52  70  68  68  80  94  57  57  90  65  64  91
#   62  93  93  65  97  51  82  66  81  79  77  53 100  99  79  79  61  88
#   98  60  62  87  57  81  98  86  79  58  78  63  87  55  85  80  54  62
#   57  75  73  71  52  85  91  71  51  76 100  87  53  70  61  66  97 100
#   84  72 100  91  74  64  62  62  83  87  58  91  62  75  83  95  53  75
#   95  71  74  88  80  76  69  99  90  53  69  95  69  53  52  90  60  63
#   75  92  77  78  51  76  97  72  76  80  99  77  91  89  79  77  70  60
#  100  51  86  77  93  78  82  58 100  58  66  58  98  57  64  72  94  94
#   98  88  74  96 100  66  88  92  77  73  85  89  53  79  74  53  53  76
#   71  81  95  62  81  90  69  53  95  89  57  65  80  91  88  65  84  91
#   80  51  61  52  79  53  93  97  97  72  77  53  85  56  72  57  61  84
#   82  82  98  70  58  79  60  53  99  57  59  59  85  56  64  70  85  51
# ...

# %%
np.corrcoef(x,z)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
plt.scatter(x,z)
plt.show()

# %%
import pandas as pd
df=pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,10,1000)
df['c']=100-df['a']+np.random.normal(0,5,1000)
df['d']=np.random.randint(0,5,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.828311 -0.943527 -0.027924
# b  0.828311  1.000000 -0.779751 -0.026168
# c -0.943527 -0.779751  1.000000  0.030131
# d -0.027924 -0.026168  0.030131  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

data=pd.read_csv("/content/House_Rent_Dataset.csv")
data.shape
# Out:
# (4746, 12)

# %%
data.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
data['Rent'].describe()
# Out:
# count    4.746000e+03
# mean     3.499345e+04
# std      7.810641e+04
# min      1.200000e+03
# 25%      1.000000e+04
# 50%      1.600000e+04
# 75%      3.300000e+04
# max      3.500000e+06
# Name: Rent, dtype: float64

# %%
corremat= data.corr()
f,ax=plt.subplots(figsize = (9,8))
sns.heatmap(corremat, ax= ax, cmap="YlGnBu", linewidths=0.1, annot=True)
# Out:
# <ipython-input-13-e91b88982703>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corremat= data.corr()
# <Axes: >
